# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Дмитрий :)
#
# Спасибо за работу на проекте, за все исправления и комментарии
#
# Стоит вернуться к алгоритму заполнения пропусков, если он вызывает появление аномалий, в т.ч. видимых на графике, оптимальнее применить заглушку или оставить пропуски (важное примечание — на этом проекте)
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Дмитрий :) Спасибо за все исправления и комментарии
#
# Критические ❌ комментарии остались
#
#
#
# + завершить фильтрацию редких значений в п. 2.4
# + поправить выполнение (закомментировать ошибочный параметр) и исследовать аномалии в п.4.5
#
# добавил подсказки и бонус
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-info">
# <b>Маленькое предупрежение</b>
#
# Во время работы часто сталкивался с неполадками тренажера, которые проявлялись в том, что переприсвоение таблицы меняло ее не только в ячейках после, но и в ячейках до. Поэтому во время предобработки данных часто создавал новую переменную для датафрейма `data_upd1` - `data_upd6`. Знаю, что так делать нежелательно, но этот способ упростил работу.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Дмитрий :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
pd.set_option('display.max_columns', None)
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит делить блок загрузки библиотек и код загрузки датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
data.hist(bins=20, figsize=(15, 20));

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#     array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
#
# data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> не помешает добавить вывод после первого знакомства с данными и познакомиться со структурой датасета при помощи data.info()

# %% [markdown]
# ### Предобработка данных

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />По оси абцисс не хватает единицы измерения - %

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# За поворот текста отвечает параметр rot, можно добавить обозначение оси х (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Изменим формат даты. Перевод с UTC на МСК не имеет смысла, так как время во всей таблице отсутствует. Датасет охватывает данные с 27 ноября 2014 года по 3 мая 2019 года. Cохраним результат в `data_upd1`.

# %%
data_upd1 = data
data_upd1['first_day_exposition'] = pd.to_datetime(data_upd1['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
print(data_upd1['first_day_exposition'].min(), data_upd1['first_day_exposition'].max())
# Out:
# 2014-11-27 00:00:00 2019-05-03 00:00:00

# %% [markdown]
# В исходном датасете не имеют пропуски столбцы: `'total_images'`, `'last_price'`, `'total_area'`, `'first_day_exposition'`, `'rooms'`, `'floor'`, `'studio'` и `'open_plan'`. В остальных они имеются.
#
# Уберем неявные дубликаты в `'locality_name'`. Это может показаться преждевременным, но дальнейшее заполнение пропусков будет зависеть от населенного пункта.

# %%
# Выведем список уникальных значений населенных пунктов
data_upd1['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Cтолбец `'locality_name'` имеет 49 пропусков. Удалим их.

# %%
data_upd1 = data_upd1.dropna(subset=['locality_name'])
data_upd1.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
def uniq_lical_name_sord(row):
    '''Функция, которая убирает неявные дубликаты в названиях населенных пунстов'''
    # пустой список с названинем нас. пункта
    uniq_local_name = []
    # пустой список с типом нас.пункта
    uniq_local = []
    for i in row:
        s = i.split(' ')
        for m in s:
            if m.istitle():
                uniq_local_name.append(i[i.find(m):])
                if len(s) == 1:
                    uniq_local.append(None) # если город, то передаем в список None
                elif s[0].istitle() and s[1].istitle():
                    uniq_local.append(None)
                else:
                    uniq_local.append(s[0]) # если не город, то передаем в список первое слово
                break
    # создаем df с именем и типом нас. пунктов.
    df_uniq_lical_name = pd.DataFrame({'name': uniq_local_name, 'local': uniq_local})
    # удаляем из списка все города
    df_uniq_lical_name = df_uniq_lical_name.dropna().reset_index(drop=True)

    # меняем повторяющиеся названия типов нас. пунктов
    for pos in ['городской', 'посёлок', 'коттеджный']:
        df_uniq_lical_name['local'] = (df_uniq_lical_name['local'].where(df_uniq_lical_name['local'] != pos, 'поселок'))
    for sad in ['садовое', 'садоводческое']:
        df_uniq_lical_name['local'] = (df_uniq_lical_name['local'].where(df_uniq_lical_name['local'] != sad, 'садоводческое товарищество'))

    # вычисляем количесво повторов населенных пунктов
    df_uniq_lical_name_sord = df_uniq_lical_name.groupby(['name'])['local'].count()
    # оставляем повторяющиеся
    df_uniq_lical_name_sord = df_uniq_lical_name_sord[df_uniq_lical_name_sord > 1]
    # объединяем отсортированные повторяющиеся населенные пункты
    df_uniq_lical_name_sord = df_uniq_lical_name.merge(df_uniq_lical_name_sord, on='name', how='right').drop_duplicates().reset_index(drop=True)
    df_uniq_lical_name_sord.columns = ['name', 'local', 'count']
    return df_uniq_lical_name_sord

uniq_lical_name = uniq_lical_name_sord(data_upd1['locality_name'].unique())
uniq_lical_name.head()
# Out:
#             name    local  count
# 0         Аннино  поселок      2
# 1  Большая Ижора  поселок      2
# 2          Бугры  поселок      2
# 3         Вещево  поселок      2
# 4    Возрождение  поселок      2

# %%
def local_name(row):
    '''Функция, избавляющая неявные дубликаты населенных пунктов'''
    for i in range(len(uniq_lical_name['name'])):
        if uniq_lical_name.loc[i, 'name'] in row:
            return uniq_lical_name.loc[i, 'local'] + ' ' + uniq_lical_name.loc[i, 'name']
    return row

# %%
data_upd1['locality_name'] = data_upd1['locality_name'].apply(local_name)
data_upd1['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'поселок Янино-1',
#        'посёлок Парголово', 'поселок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок Красный Бор', 'Гатчина', 'деревня Фёдоровское', 'Выборг',
#        'Кронштадт', 'Кировск', 'деревня Новое Девяткино',
#        'посёлок Металлострой', 'поселок Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок Кузьмоловский', 'садовое товарищество Новая Ропша',
#        'Павловск', 'деревня Пикколово', 'Всеволожск', 'Волхов',
#        'Кингисепп', 'Приозерск', 'Сестрорецк', 'деревня Куттузи',
#        'поселок Аннино', 'поселок городского типа Ефимовский',
#        'посёлок Плодовое', 'деревня Заклинье', 'поселок Торковичи',
#        'поселок Первомайское', 'Красное Село', 'посёлок Понтонный',
#        'Сясьстрой', 'деревня Старая', 'деревня Лесколово',
# ...

# %% [markdown]
# Избавившись от неявных дубликатов, избавимся от явных дубликатов во всей таблице

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит исключить предупреждения. Иногда их бывает слишком много, поэтому важно уметь их скрывать. В этом тебе поможет библиотека warnings. Попробуй найти подходящий метод и убрать предупреждения.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Исключил преупреждения, добавив warnings.filterwarnings('ignore')

# %%
# check
data_upd1.locality_name.nunique()
# Out:
# 308

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />хорошая работа по избавлению от неявных дубликатов

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# Для того, __чтобы изменить лишь часть строки,__ можно добавить к коду — .str
#
#         .str.replace('посёлок','поселок')
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.replace.html

# %%
data_upd1 = data_upd1.drop_duplicates()
data_upd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  datetime64[ns]
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        14490 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               12137 non-null  float64
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# + дополнительно — на рабочих проектах стоит искать дубликаты по сумме ключевых параметров (подмножеству), для примера:
#
#  + общ. площадь квартиры,
#  + этаж,
#  + общая этажность дома,
#  + расстояние до центра
#  + название населенного пункта
#  + кол-во комнат
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# Изучим пропущеные значения в `'ceiling_height'`. По гистограмме в самом начале проекта можно заметить очень высокие значения, на порядок больше разумной высоты потолка.

# %%
# Посмотрим список уникальных значений высоты потолков
# Очевидно, что в значениях от 20 до 100 м знак десятичой части стоит неверно.
data_upd1['ceiling_height'].value_counts().sort_index(ascending=False).head(10)
# Out:
# 100.0    1
# 32.0     2
# 27.5     1
# 27.0     8
# 26.0     1
# 25.0     7
# 24.0     1
# 22.6     1
# 20.0     1
# 14.0     1
# Name: ceiling_height, dtype: int64

# %%
#делим все значения площади более 20 м, переприсваиявая значение таблицы data_n
data_upd1.loc[data_upd1['ceiling_height'] >= 20, 'ceiling_height'] = data_upd1.loc[data_upd1['ceiling_height'] >= 20, 
                                                                                   'ceiling_height']/10
data_upd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  datetime64[ns]
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        14490 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               12137 non-null  float64
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %%
data_upd1['ceiling_height'].describe()
# Out:
# count    14490.000000
# mean         2.729355
# std          0.319691
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max         14.000000
# Name: ceiling_height, dtype: float64

# %%
data_upd1.boxplot('ceiling_height')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Заполним недостающие значения в `'ceiling_height'` медианным для каждого населенного пункта

# %%
def add_median_ceiling(df):
    '''Функция определения медианного значения высоты потолка для каждого населенного пункта'''
    median = df['ceiling_height'].median()
    df.loc[pd.isna(df['ceiling_height']), 'ceiling_height'] = median
    return df

# %%
#заменим все пропущенные значения на медианное для кажого населенного пункта
data_upd2 = data_upd1.groupby('locality_name').apply(add_median_ceiling)
display(data_upd2['ceiling_height'].isna().sum())

# Остались еще незаполненные значения. Заполним их общей медианной
data_upd2['ceiling_height'] = data_upd2['ceiling_height'].fillna(data_upd2['ceiling_height'].median())
# Out:
# 96

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />При заполнении средним или медианой необходимо четко отслеживать изменение других статистик: стандартное отклонение, дисперсию и другие параметры выборки
#
# ... если рассмотреть районность высоты потолков, т.к. в современных районах Питера высота потолков будет ожидаема ниже, чем в исторических, мы увидим, что заполнение подобного объема пропусков медианой или средним значением «размажет» это отличительное свойство объектов недвижимости в центре Питера
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Размажет - уменьшится std? То есть желательно знать год постройки дома, чтобы отделить исторические и новые дома? Или достаточно ориентироваться по расстоянию от центра, приняв что центр - до 10 км, например, и все квартиры внутри этого порога исторические? Как тогда в этом случае учесть новые дома с высокими потолками?

# %%
# check
data.plot(x='cityCenters_nearest', y='ceiling_height', style='o', alpha=0.5, figsize = (15,4))
plt.title('Высота потолков в зависимости от удаленности от центра')
plt.xlabel('Близость к центру Спб, м')
plt.ylabel('Высота потолков, м')
plt.ylim(2,4.5)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Частичное решение — график
#
# задача с заполнением даже такой простой выборки как высота потолков сталкивается со множеством вопросов, молодец, что отмечаешь их
#
# решение будет зависеть от главной задачи проекта — требуется ли нам подобная точность или нет

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Есть подход, в котором высота потолка, меньшая 2.5 м, заменяется строго на 2.5, так как по правилам СанПина она не может быть ниже. Что меньшее зло: заменить на 2.5 м, или исключить такие низкие потолки их вовсе?

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Если их кол-во минимально, на этом проекте, с этой главной задачей проекта, можно удалить

# %%
data_upd2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  datetime64[ns]
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        23650 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               12137 non-null  float64
# ...

# %% [markdown]
# Заполним в столбцах `'floors_total'` и `'living_area'` пропущенные значения на медианные. В `'living_area'` рассчитаем в зависимости от количества комнат в квартире, а в `'floors_total'` в зависимости от населенного пункта.
# В стобцах `'floors_total`, `'rooms'`, `'total_images'` и `'floor'` изменим тип на `int`

# %%
# Проверяем уникальные значения кол-ва комнат
data_upd2['rooms'].unique()
# Out:
# array([ 3,  1,  2,  4,  5,  6,  0,  7, 11,  8, 14, 10, 15,  9, 19, 16, 12])

# %%
def add_median_area(df):
    '''Функция определения медианного значения для жилой площади'''
    median = df['living_area'].median()
    df.loc[pd.isna(df['living_area']), 'living_area'] = median
    return df

def add_median_floors_total(df):
    '''Функция определения медианного значения для этажности дома'''
    median = df['floors_total'].median()
    df.loc[pd.isna(df['floors_total']), 'floors_total'] = median
    return df

# %%
# Медиана для жилой площади в зависимости от кол-ва комнат в квартире
data_upd3 = data_upd2.groupby('rooms').apply(add_median_area)
display(data_upd3['living_area'].isna().sum())

# Медиана для этажности в зависимости от нас. пункта
data_upd4 = data_upd3.groupby('locality_name').apply(add_median_floors_total)
display(data_upd4['floors_total'].isna().sum())
# Out:
# 0
# 0

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После заполнения синтетическими данными, стоит провести проверку на корректность значений по условию (этажность дома не м.б. ниже этажности квартиры)
#
#     ['floors_total'] < ['floor']

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Точно!
#         Заменил по условию: если этаж квартиры больше общей этажности здания, то квартира находится на последнем этаже

# %%
(data_upd4
 .loc[data_upd4['floors_total'] < data_upd4['floor'], 'floor']) = (data_upd4
 .loc[data_upd4['floors_total'] < data_upd4['floor'], 'floors_total'])
data_upd4.query('floors_total < floor').shape[0]
# Out:
# 0

# %%
data_upd4['floors_total'] = data_upd4['floors_total'].astype('int')
data_upd4['rooms'] = data_upd4['rooms'].astype('int')
data_upd4['total_images'] = data_upd4['total_images'].astype('int')
data_upd4['floor'] = data_upd4['floor'].astype('int')

# %%
data_upd4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  datetime64[ns]
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        23650 non-null  float64
#  6   floors_total          23650 non-null  int64
#  7   living_area           23650 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               12137 non-null  float64
# ...

# %% [markdown]
# В столбце `'is_apartment'` помимо маркера принадлежности к апартаментам имелись численные значения, дублирующие значения жилой площади. Более того, 88% строк имеют пропуски. Это больше, чем очень много. Но так как для исследования данный столбец не потребуется, можно либо вообще его исключить, либо принять, что пропуск говорит об не принадлежности к апартаментам. Также изменим тип на булев.

# %%
data_upd4['is_apartment'] = data_upd4['is_apartment'].fillna(False)
data_upd4['is_apartment'] = data_upd4['is_apartment'].where(data_upd4['is_apartment'].isin([True, False]), False).astype('bool')

# %% [markdown]
# Аналогично поступим со столбцами `'studio'` и `'open_plan'`, в которых помимо `True` и `False` были значения высоты потолков.

# %%
data_upd4['studio'] = data_upd4['studio'].where(data_upd4['studio'].isin([True, False]), False).astype('bool')
data_upd4['open_plan'] = data_upd4['open_plan'].where(data_upd4['open_plan'].isin([True, False]), False).astype('bool')

# %% [markdown]
# Отсутствие значения в столбце `'balcony'` будем считать отсутствием балкона. Также в столбце имелись дробные значения, равные высоте потолка. Заменим данные значения на наиболее встречаемое - 1 (имеется один балкон). Также изменим тип на `int`.

# %%
data_upd4['balcony'] = data_upd4['balcony'].fillna(0)
data_upd4['balcony'] = data_upd4['balcony'].where(data_upd4['open_plan'] % 1 == 0, 1).astype('int')

# %%
data_upd4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  datetime64[ns]
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        23650 non-null  float64
#  6   floors_total          23650 non-null  int64
#  7   living_area           23650 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  bool
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               23650 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Перейдем к пропускам в `'kitchen_area'`. Добавим столбец с относительной площадью кухни от общей площади квартиры `'relative_kitchen_area'`. Определим медианное значение относительной площади кухни для каждого значения кол-ва комнат. Заполним пропуски произведением медианного значения на общую площадь.
# Однако данный метод группировки не применим для студий и квартир со свободной планировкой (rooms = 0). Также появились квартиры, в которых сумма жилой площади и кухни больше общей площади. Заполним данные квартиры разницей общей и жилой площадью. Появилось 158 квартир с площадью кухни менее 2 кв.м. Это могло произойти на моменте заполнения обьявления из-за неверного значения жилой площади, которая почти равна общей. Удалим данные строки

# %%
def add_median_floors_kitchen_area(df):
    '''Функция определения площади кухни через медианную относительную площадь для каждого значения кол-ва комнат'''
    median = df['relative_kitchen_area'].median()
    df.loc[pd.isna(df['kitchen_area']), 'kitchen_area'] = median * df['total_area'] * 0.9
    return df

# %%
# Добавим столбец с относительной площадью кухни
data_upd4['relative_kitchen_area'] = data_upd4['kitchen_area'] / data_upd4['total_area']

# Убедимся, в корректности граничных значений
display(data_upd4['relative_kitchen_area'].min(), data_upd4['relative_kitchen_area'].max())

# Рассчитаем меианное значение относительной площади для каждого значения кол-ва комнат
data_upd5 = data_upd4.groupby('rooms').apply(add_median_floors_kitchen_area)

# Заполняем пропуски разницой между общей и жилой площадью для rooms = 0 и неверно подсчитанных квартир
data_upd5['kitchen_area'] = data_upd5['kitchen_area'].fillna(data_upd5['total_area'] * 0.9 - data_upd5['living_area'])
filtr = (data_upd5['living_area'] + data_upd5['kitchen_area']) >= data_upd5['total_area'] * 0.9
data_upd5.loc[filtr, 'kitchen_area'] = data_upd5['total_area']*0.9 - data_upd5['living_area']

# Появилось 158 квартир с площадью кухни менее 2 кв.м.
# Это могло произойти из-за неверного значения жилой площади, которая почти равна общей. Удалим данные строки
display(data_upd5.query('kitchen_area <= 2').shape[0])
data_upd5 = data_upd5.query('kitchen_area > 2')
# Out:
# 0.025380710659898477
# 0.7878787878787878
# 158

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После заполнения синтетическими данными столбцов, стоит провести проверку на корректность значений всех наших площадей, т.к. есть (коридоры, сан.узлы, балконы)
#
#         total_area*0.9 <= (living_area + kitchen_area)
#
# если алгоритм приводит к появлению аномалий, стоит подумать над его содержимым

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Сделал в ячейке выше под '# Заполняем пропуски разницой между общей и жилой площадью для rooms = 0 и неверно подсчитанных квартир', умножив total_area на 0.9.
#         Кол-во удаленных квартир с площадью кухни <= 2 кв.м. увеличилось с 61 до 158.
#         Проверил по условию total_area*0.9 < (living_area + kitchen_area),  так как квартиры с условием total_area*0.9 = (living_area + kitchen_area) нам подходят

# %%
data_upd5.query('total_area*0.9 < (living_area + kitchen_area)').shape[0]
# Out:
# 0

# %%
# check
data_upd5[data_upd5['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'black', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Аномалии проявились на графике (прямая неестественная для облака линия) — стоит принять решение или изменить алгоритм заполнения пропусков, или оставить пропуски, или заполнить маркерами
#
# при изменении способа обработки колонок, стоит перепроверить код фильтрации
#
# __Самое важное — приобрести навык__ — любая замена пропусков очень трудоемка по ресурсам, т.к. приходится искать оптимальный вариант и если можно работать, имея пропуски в данных — лучше отказаться от заполнения
#
# но есть другие случаи, когда пропуски заполнять обязательно нужно, на проекте по стат. анализу — внимательно посмотри на пропуски в данных в объединенной таблице (кроме даты оттока клиентов)
#
# в итоге каждый раз мы вынуждены будем принимать решение — заполнять пропуски и как заполнять, или оставлять

# %%
data_upd5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23492 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total_images           23492 non-null  int64
#  1   last_price             23492 non-null  float64
#  2   total_area             23492 non-null  float64
#  3   first_day_exposition   23492 non-null  datetime64[ns]
#  4   rooms                  23492 non-null  int64
#  5   ceiling_height         23492 non-null  float64
#  6   floors_total           23492 non-null  int64
#  7   living_area            23492 non-null  float64
#  8   floor                  23492 non-null  int64
#  9   is_apartment           23492 non-null  bool
#  10  studio                 23492 non-null  bool
#  11  open_plan              23492 non-null  bool
#  12  kitchen_area           23492 non-null  float64
#  13  balcony                23492 non-null  int64
# ...

# %% [markdown]
# Перейдем к пропускам в картографических данных. Пропуски в `'airports_nearest'` определим как медианное для конкретного населенного пункта. Аналогично поступим с `'cityCenters_nearest'`, так как, судя по данным, это расстояние до центра не конкретного населенного пункта, а до центра Санкт-Петербурга.
# Схожим способом поступим с расстоянием до ближайшего парка в `'parks_nearest'` и водоема `'ponds_nearest'`, а также их число в радиусе 3км. Это будет справедливо как для маленьких населенных пунстов, так и для Санкт-Петербурга, в котором огромное количество парков и водоемов.
# Столбцы `'ponds_around3000'` и `'parks_around3000'` обозначают количество парков и водоемов в заданном радиусе, поэтому данные столбцы должны быть типа `int`. Но недостающие значения непозволят преобразовать через `astype()`, поэтому заполним их нулями.
# Однако данный способ заполнит не все количество пропусков. Для заполнения оставшихся необходимы координаты квартир.
# Также будем считать, что в столбце `'days_exposition'` пропуски означают 0 - обьявленние снялось в тот же день, когда опубликовалось. Изменим тип этого столбца на `int`.

# %%
def add_median_airports_nearest(df):
    '''Функция определения медианного значения расстояния до аэропорта'''
    median = df['airports_nearest'].median()
    df.loc[pd.isna(df['airports_nearest']), 'airports_nearest'] = median
    return df

def add_median_cityCenters_nearest(df):
    '''Функция определения медианного значения расстояния до аэропорта'''
    median = df['cityCenters_nearest'].median()
    df.loc[pd.isna(df['cityCenters_nearest']), 'cityCenters_nearest'] = median
    return df

def add_median_parks_nearest(df):
    '''Функция определения медианного значения расстояния до парка'''
    median = df['parks_nearest'].median()
    df.loc[pd.isna(df['parks_nearest']), 'parks_nearest'] = median
    return df

def add_median_ponds_nearest(df):
    '''Функция определения медианного значения расстояния до водоема'''
    median = df['ponds_nearest'].median()
    df.loc[pd.isna(df['ponds_nearest']), 'ponds_nearest'] = median
    return df

def add_median_parks_around3000(df):
    '''Функция определения медианного значения числа парков'''
    median = df['parks_around3000'].median()
    df.loc[pd.isna(df['parks_around3000']), 'parks_around3000'] = median
    return df

def add_median_ponds_around3000(df):
    '''Функция определения медианного значения числа водоемов'''
    median = df['ponds_around3000'].median()
    df.loc[pd.isna(df['ponds_around3000']), 'ponds_around3000'] = median
    return df


data_upd6 = data_upd5.groupby('locality_name').apply(add_median_airports_nearest)
data_upd6 = data_upd6.groupby('locality_name').apply(add_median_cityCenters_nearest)
data_upd6 = data_upd6.groupby('locality_name').apply(add_median_parks_nearest)
data_upd6 = data_upd6.groupby('locality_name').apply(add_median_ponds_nearest)
data_upd6 = data_upd6.groupby('locality_name').apply(add_median_parks_around3000)
data_upd6 = data_upd6.groupby('locality_name').apply(add_median_ponds_around3000)

# Заполним оставшиеся пропуски в parks_around3000 и ponds_around3000 нулями и изменим тип на int
data_upd6['ponds_around3000'] = data_upd6['ponds_around3000'].fillna(0).astype('int')
data_upd6['parks_around3000'] = data_upd6['parks_around3000'].fillna(0).astype('int')
# Изменим тип в столбце с количесвом дней на int
data_upd6['days_exposition'] = data_upd6['days_exposition'].fillna(0).astype('int')

data_upd6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23492 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total_images           23492 non-null  int64
#  1   last_price             23492 non-null  float64
#  2   total_area             23492 non-null  float64
#  3   first_day_exposition   23492 non-null  datetime64[ns]
#  4   rooms                  23492 non-null  int64
#  5   ceiling_height         23492 non-null  float64
#  6   floors_total           23492 non-null  int64
#  7   living_area            23492 non-null  float64
#  8   floor                  23492 non-null  int64
#  9   is_apartment           23492 non-null  bool
#  10  studio                 23492 non-null  bool
#  11  open_plan              23492 non-null  bool
#  12  kitchen_area           23492 non-null  float64
#  13  balcony                23492 non-null  int64
# ...

# %% [markdown]
# Разберемся с выбивающимися значениями. Построем гистограмму для всей таблицы

# %%
data_upd6.hist(bins=20, figsize=(15, 20));

# %% [markdown]
# Очистим от выбросов столбцы `'ceiling_height'`, `'kitchen_area'`, `'total_area'`, `'floors_total'` оставив квартиры:
# - с высотой потолка от 2 до 4 м
# - с площадью кухни менее 20 кв.м (менее 2 кв.м. исключили ранее)
# - с площадью кухни менее 200 кв.м
# - ниже 30 этажа включительно
#
# Таким образом таблица сократилась на 6.15% от исходного.
#
# Аномальные значения могли возникнуть либо из-за человеческого фактора (неправильно указали), либо из-за уникальности квартиры.

# %%
pre_total = data_upd6.query('(2 < ceiling_height < 4) and (kitchen_area < 20) and \
                            (15 < total_area < 200) and (floors_total <= 30)')

pre_total.hist('floors_total', bins=10);

# %%
pre_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22190 entries, 1 to 23698
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total_images           22190 non-null  int64
#  1   last_price             22190 non-null  float64
#  2   total_area             22190 non-null  float64
#  3   first_day_exposition   22190 non-null  datetime64[ns]
#  4   rooms                  22190 non-null  int64
#  5   ceiling_height         22190 non-null  float64
#  6   floors_total           22190 non-null  int64
#  7   living_area            22190 non-null  float64
#  8   floor                  22190 non-null  int64
#  9   is_apartment           22190 non-null  bool
#  10  studio                 22190 non-null  bool
#  11  open_plan              22190 non-null  bool
#  12  kitchen_area           22190 non-null  float64
#  13  balcony                22190 non-null  int64
# ...

# %% [markdown]
# Таким образом была выполнена предопработка данных.

# %% [markdown]
# #### check gap

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    pre_total[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max', 'median'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_6607e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6607e_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_6607e_row0_col0" class="data row0 col0" >22,190.00</td>
#                         <td id="T_6607e_row0_col1" class="data row0 col1" >22,190.00</td>
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'rooms', 'days_exposition',  'living_area',  'kitchen_area'
#
# стоит обратить внимание на минимальные и максимальные значения в выборке и учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Доп. задание, на твое усмотрение — сможешь добавить в таблицу расчет медианного значения?
#
#         (
#             data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
#                   'floor', 'floors_total']]
#             .apply (['count', 'min', 'max'])
#             .style.format("{:,.2f}")
#         )

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Добавил)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="5", color = "black">
# <br />😉

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
# check

try:
    df_check = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')
# если не получилось прочитать файл из локальной папки, то загружаем данные из сети
except:
    df_check = pd.read_csv('real_estate_data.csv', sep='\t')

# %%
# check
df_check.rooms.value_counts().to_frame()
# Out:
#     rooms
# 1    8047
# 2    7940
# 3    5814
# 4    1180
# 5     326
# 0     197
# 6     105
# 7      59
# 8      12
# 9       8
# 10      3
# 11      2
# 14      2
# 19      1
# 16      1
# 12      1
# 15      1

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 20-ти и более 250-ти квадратных метров можно считать редкостями

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (0,25));

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось завершить выполнение пункта 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_5a27d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5a27d_level0_row0" class="row_heading level0 row0" >0.0012</th>
#                         <td id="T_5a27d_row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_5a27d_row0_col1" class="data row0 col1" >20.00</td>
# ...

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    pre_total[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_76110_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76110_level0_row0" class="row_heading level0 row0" >0.0012</th>
#                         <td id="T_76110_row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_76110_row0_col1" class="data row0 col1" >21.59</td>
# ...

# %%
pre_total = pre_total[
    (pre_total['rooms'] <= pre_total['rooms'].quantile(0.9988)) &
    (pre_total['rooms'] >= pre_total['rooms'].quantile(0.0012)) &
    (pre_total['kitchen_area'] >= pre_total['kitchen_area'].quantile(0.01)) &
    (pre_total['living_area'] >= pre_total['living_area'].quantile(0.0012)) &
    (pre_total['days_exposition'] <= pre_total['days_exposition'].quantile(0.9988))
]
pre_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21913 entries, 1 to 23698
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total_images           21913 non-null  int64
#  1   last_price             21913 non-null  float64
#  2   total_area             21913 non-null  float64
#  3   first_day_exposition   21913 non-null  datetime64[ns]
#  4   rooms                  21913 non-null  int64
#  5   ceiling_height         21913 non-null  float64
#  6   floors_total           21913 non-null  int64
#  7   living_area            21913 non-null  float64
#  8   floor                  21913 non-null  int64
#  9   is_apartment           21913 non-null  bool
#  10  studio                 21913 non-null  bool
#  11  open_plan              21913 non-null  bool
#  12  kitchen_area           21913 non-null  float64
#  13  balcony                21913 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Исходный датасет истощал на 7.5%

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир

(
    pre_total[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_d031c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d031c_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_d031c_row0_col0" class="data row0 col0" >21,913.00</td>
#                         <td id="T_d031c_row0_col1" class="data row0 col1" >21,913.00</td>
# ...

# %%
pre_total.loc[(pre_total['days_exposition'] == 1) | (pre_total['days_exposition'] == 2), 'days_exposition' ] = 0

# %%
# check
pre_total.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5));

pre_total.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %%
pre_total.hist(column = 'kitchen_area', bins = 60, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#           'days_exposition',    'kitchen_area'
#
# для определения хвостов, редкостей и аномалий смотрим на минимальные и максимальные значения, строим несколько гистограмм по каждому параметру
#
# например в таблице мы видим аномалию квартиру с кухней в 2,5 кв. метра ..., а на гистограмме аномальную скорость продаж в один или два дня
#
# стоит учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Присвоил 4м аномальным квартирам со скоростью продажи 1 и 2 дня маркер "0". В площади кухни установил нижний порог квартилем выше (0.01 вместо 0.0012). Правый хвост необходимо оставить, иначе мы потеряем больше 10% исходных данных

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Принимается

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
total = pre_total.loc[: , 'total_images' : 'days_exposition'].reset_index(drop=True)

# Посчитаем и добавим в таблицу цену одного квадратного метра
total['price_area'] = total['last_price'] / total['total_area']

# Добавим столбцы с днем публикации объявления (0 - понедельник, 1 - вторник и т.д.), месяцем и годом публикации объявления
total['weekday_exposition'] = total['first_day_exposition'].dt.weekday
total['month_exposition'] = total['first_day_exposition'].dt.month
total['year_exposition'] = total['first_day_exposition'].dt.year

total.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0             7   3350000.0        40.4           2018-12-04      1
# 1            10   5196000.0        56.0           2015-08-20      2
# 2             0  64900000.0       159.0           2015-07-24      3
# 3            10   2890000.0        30.4           2018-09-10      1
# 4             6   3700000.0        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.63            11         18.6      1         False   False
# 1            2.70             5         34.3      4         False   False
# 2            2.70            14         45.0      9         False   False
# 3            2.65            12         14.4      5         False   False
# 4            2.64            26         10.6      6         False   False
#
#    open_plan  kitchen_area  balcony      locality_name  airports_nearest  \
# ...

# %%
# Добавляем столбец с типом этажа квартиры (значения — «первый», «последний», «другой»)
total['floor_category'] = total['floor']
total['floor_category'] = total['floor_category'].where((total['floor'] == 1) & (total['floors_total'] == total['floor']), 'другой')
total['floor_category'] = total['floor_category'].where((total['floor'] != total['floors_total']), 'последний')
total['floor_category'] = total['floor_category'].where((total['floor'] != 1), 'первый')

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поработать над алгоритмом, в результате у нас появилось несколько записей, когда первые этажи попали в категорию последних
#
#         total['floor_category'] = total['floor']
#         total['floor_category'] = total['floor_category'].where((total['floor'] == 1) & (total['floors_total'] == total['floor']), 'другой')
#         total['floor_category'] = total['floor_category'].where((total['floor'] != 1), 'первый')
#         total['floor_category'] = total['floor_category'].where((total['floor'] != total['floors_total']), 'послений')

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Исправил

# %%
total.query('(floor_category == "последний") and (floor == 1)').shape[0]
# Out:
# 0

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит учесть крайние условия: нулевые и отрицательные значения
#
# плюс оптимальнее использовать функцию, чтобы три раза не обращаться к датасету

# %%
# Добавляем столбец с расстоянием в км до центра города
total['cityCenters_nearest_km'] = round(total['cityCenters_nearest'] / 1000)
total.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0             7   3350000.0        40.4           2018-12-04      1
# 1            10   5196000.0        56.0           2015-08-20      2
# 2             0  64900000.0       159.0           2015-07-24      3
# 3            10   2890000.0        30.4           2018-09-10      1
# 4             6   3700000.0        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.63            11         18.6      1         False   False
# 1            2.70             5         34.3      4         False   False
# 2            2.70            14         45.0      9         False   False
# 3            2.65            12         14.4      5         False   False
# 4            2.64            26         10.6      6         False   False
#
#    open_plan  kitchen_area  balcony      locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остальные данные добавлены корректно, молодец

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %%
study = total[['total_area', 'living_area', 'kitchen_area', 'last_price', 'rooms', 
               'ceiling_height', 'floor', 'floor_category', 'floors_total', 'cityCenters_nearest', 'airports_nearest',
              'parks_nearest', 'weekday_exposition', 'month_exposition']]
study.hist(bins=50, figsize=(15, 20));

# %%
study['floor_category'].hist()
plt.ylabel('Количество')
plt.xlabel('Категория этажей');

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики, стоит добавить оформление
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас трудно определить границу резкого снижения кол-ва объявлений, или на 1-ке, или на 5-ке, или на 6-ке ...
#
# и
#
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас трудно определить типовую высотность зданий
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно, почему февраль (самый короткий месяц) опережает все месяцы — ?__

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Пришли в себя после новогодних праздников и пытаются успеть продать до майских)
#         Или это как-то связано с ЧМ 2018 по футболу. Возможно, успешные рекламные компании в начале 2018 и 2019 годов.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит смотреть на цифры и графики
#
# Можно посмотреть на каждый февраль из нашей выборки, а затем __на каждый день особого февраля__ ..., особенно на февраль 2018 года

# %%
# Кол-во объявлений в феврале по годам
fevr_month = total[total['month_exposition'] == 2].groupby('year_exposition')['month_exposition'].count().reset_index()
# Общее кол-во объявлений в феврале по годам
total_month= total.groupby('year_exposition')['month_exposition'].count().reset_index()

svod = (fevr_month
 .merge(total_month, on='year_exposition')
 .rename(columns={'month_exposition_x' : 'fevr', 'month_exposition_y' : 'total_month'}))
svod['share'] = svod['fevr'] / svod['total_month']
display(svod)
# Out:
#    year_exposition  fevr  total_month     share
# 0             2015    48         1034  0.046422
# 1             2016   237         2573  0.092110
# 2             2017   401         7603  0.052742
# 3             2018  1238         7949  0.155743
# 4             2019   509         2659  0.191425

# %%
(
total.query('year_exposition == 2018 and 1 <= month_exposition <= 2')
    .groupby('first_day_exposition')['first_day_exposition'].count()
    .plot(x='first_day_exposition', figsize=(15, 8), grid=True, title='Распределение публикаций объявлений в январе/феврале 2018 года')
)
plt.xlabel('Дата')
plt.ylabel('Количество объявлений')
# Out:
# Text(0, 0.5, 'Количество объявлений')

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> При отрисовке графиков стоит исключать значения-заглушки, которыми мы заполнили пропуски, они мешают рассматривать реальную картину
#
# ![image.png](attachment:image.png)

# %%
data['parks_nearest'].hist(bins=30).set_title('Распределение расстояния до парков')
plt.ylabel('Количество')
plt.xlabel('Расстояние до парков')
# Out:
# Text(0.5, 0, 'Расстояние до парков')

# %% [markdown]
# - наибольшее количество объявлений квартир с общей площадью от 30 до 50 кв.м., жилой площадью от 20 до 40 кв.м., площадью кухни от 6 до 11 кв.м.
# - наиболее часто встречаемая стоимось квартир от 3 до 6 млн.
# - однокомнатные и двухкомнатные квартиры публикуются чаще трехкомнатных. 4хкомнатных и более почти на порядок меньше, как и свободной планировки.
# - квартир с потолком высотой 2.5 и 2.7 м подавляющее большинство.
# - чаще встречаются объявления с квартирами 1 - 5 этажи (категория "другой" почти на порядок больше, при чем последний этаж встречается чаще первого).
# - больше всего объявлений в пятиэтажных и девятиэтажных домах на расстонии 11-17 км от центра города. Имеется небольшой рост продаж квартир в близлежащих населенных пунктах.
# - почти всем квартирам в радиусе 50 км доступен аэропорт, в 500 м парк.
# - чаще всего объявления публиковались в будние дни в февраль-апрель и сентябрь-ноябрь.

# %% [markdown]
# # example 1

# %% [markdown]
# #### example 3

# %% [markdown]
# ##### example 4

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# стоит выделять разделы проекта заголовками разного уровня, за уровень отвечает количество знаков #
#
#         # example 1
#
#         #### example 3
#
#         ##### example 4

# %%
# Изучим, как быстро продавались квартиры
total['days_exposition'].hist(bins=50, figsize=(10, 5))
plt.ylabel('Количество')
plt.xlabel('Дни активности объявления')
display(total['days_exposition'].describe())
print('Медианное значение акивности объявления', total['days_exposition'].median(), 'дней')
print('Среднее значение акивности объявления', total['days_exposition'].mean(), 'дней')
# Out:
# count    21913.000000
# mean       153.201479
# std        206.291164
# min          0.000000
# 25%         23.000000
# 50%         73.000000
# 75%        195.000000
# max       1355.000000
# Name: days_exposition, dtype: float64
# Медианное значение акивности объявления 73.0 дней
# Среднее значение акивности объявления 153.20147857436226 дней

# %%
total.boxplot('days_exposition', figsize=(10, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Обычно продажа квартиры осуществляется за 73 дня (медиана). Быстрой продажу можно назвать менее чем за 23 дня (первый процентиль). Дольгой - более 194 дня, а необычно долгой - 451 день (q3 + 1.5*(q3 - q1))

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />В расчете скорости продаж не исключены нулевые заглушки, более 3000 записей с нулевой скоростью продаж искажают среднее и медианное значения
#
# Стоит пересчитать статистики скорости продажи после восстановления пропусков

# %%
# Скорости продажи после восстановления пропусков
data[data['days_exposition'] <= data['days_exposition'].quantile(0.9988)]['days_exposition'].hist(bins=50, figsize=(10, 5))
plt.ylabel('Количество')
plt.xlabel('Дни активности объявления')
display(data[data['days_exposition'] <= data['days_exposition'].quantile(0.9988)]['days_exposition'].describe())
# Out:
# count    20493.000000
# mean       179.331625
# std        215.279076
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1368.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />В данном случае, обычно продажа квартиры осуществляется за 95 дней (медиана). Быстрой продажу можно назвать менее чем за 45 дня (первый процентиль). Дольгой - более 231 дней, а необычно долгой - 510 дней (q3 + 1.5*(q3 - q1))

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# __Интересно посмотреть на изменение средней  скорости продаж по годам__

# %%
# Изменение средней скорости продаж по годам
#total.groupby('year_exposition')['days_exposition'].mean()

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Время продажи с каждым годом сокращалось. Это связано с тем, что на сервисе есть лимит по длительности активного объявления. То есть нельзя связывать скорость продажи с тем, как долго объявление висело на сайте.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         total.groupby('year_exposition')['days_exposition'].mean()
#
# Стоит пересчитать статистики средней скорости продажи — 3000 нулей ускоряют показатели ...
#
#
#         2014    770.284211
#         2015    602.924038
#         2016    312.473098
#         2017    152.219003
#         2018     83.340561
#         2019     11.839312
#
# Только использовать с осторожностью, у нас еще больше 3000 непроданных квартир, которых нет в статистике о средней скорости продаж

# %%
total.query('days_exposition > 0').groupby('year_exposition')['days_exposition'].mean()
# Out:
# year_exposition
# 2014    860.905882
# 2015    636.946939
# 2016    320.120827
# 2017    157.193194
# 2018     93.341916
# 2019     31.022682
# Name: days_exposition, dtype: float64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %%
# Зависимость цены квартиры от жилой, общей площади и площади кухни
price_area_study = study[['total_area', 'living_area', 'kitchen_area', 'last_price']]
(study.plot(x='total_area', y='last_price', kind='scatter', title='Общая цена - полная площадь', alpha=0.02)
 .set_xlabel('Полная площадь'))

study.plot(x='living_area', y='last_price', kind='scatter', title='Общая цена - жилая площадь', alpha=0.01).set_xlabel('Жилая площадь')
study.plot(x='kitchen_area', y='last_price', kind='scatter', title='Общая цена - площадь кухни', alpha=0.01).set_xlabel('Площадь кухни')
#pd.plotting.scatter_matrix(price_area_study, figsize=(10, 10))

price_area_study.corr()['last_price']
# Out:
# total_area      0.720719
# living_area     0.608852
# kitchen_area    0.486808
# last_price      1.000000
# Name: last_price, dtype: float64

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />  Можно попробовать настроить вид точечных графиков
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)

# %%
# Зависимость цены квартиры от количества комнат
price_rooms_study = study.pivot_table(index='rooms', values='last_price', aggfunc=['median'])
price_rooms_study.columns = ['median_price']
price_rooms_study.reset_index().plot.scatter(x = 'rooms', y='median_price', title='Меданная цена - количество комнат')
plt.ylabel('Полная цена')
plt.xlabel('Количество комнат')
price_rooms_study.reset_index().corr()['rooms'][1]
# Out:
# 0.9783673990796782

# %%
# Зависимость цены квартиры от категории этажа
price_floor_category_study = study.pivot_table(index='floor_category', values='last_price', aggfunc=['median'])
price_floor_category_study.columns = ['median_price']
price_floor_category_study.reset_index().plot.scatter(x = 'floor_category', y='median_price', title='Меданная цена - категория этажа')
plt.ylabel('Полная цена')
plt.xlabel('Категория этажа')
# Out:
# Text(0.5, 0, 'Категория этажа')

# %%
# Зависимость цены квартиры от дня недели публикиции
price_day_study = study.pivot_table(index='weekday_exposition', values='last_price', aggfunc=['median'])
price_day_study.columns = ['median_price']
price_day_study.reset_index().plot.scatter(x = 'weekday_exposition', y='median_price', title='Меданная цена - день недели')
plt.ylabel('Полная цена')
plt.xlabel('День недели')
price_day_study.reset_index().corr()['weekday_exposition'][1]
# Out:
# -0.526947007726087

# %%
# Зависимость цены квартиры от месяца публикации
price_month_study = study.pivot_table(index='month_exposition', values='last_price', aggfunc=['median'])
price_month_study.columns = ['median_price']
price_month_study.reset_index().plot.scatter(x = 'month_exposition', y='median_price', title='Меданная цена - месяц')
plt.ylabel('Полная цена')
plt.xlabel('Месяц')
price_month_study.reset_index().corr()['month_exposition'][1]
# Out:
# 0.08688277363916072

# %%
# Зависимость цены квартиры от года
price_year_study = total.pivot_table(index='year_exposition', values='last_price', aggfunc=['median'])
price_year_study.columns = ['median_price']
price_year_study.reset_index().plot.scatter(x = 'year_exposition', y='median_price', title='Меданная цена - год')
price_year_study.reset_index().corr()['year_exposition'][1]
plt.ylabel('Полная цена')
plt.xlabel('Год');

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров: кол-во записей и изменение средней цены и средней площади в течение лет)

# %%
# Изменение площади продаваемых квартир с годами
year_exposition_area = total.groupby('year_exposition')['total_area'].median()
year_exposition_area.reset_index().plot.scatter(x = 'year_exposition', y='total_area', title='Изменение площади продаваемых квартир с годами');
plt.ylabel('Площадь квартир')
plt.xlabel('Год')
year_exposition_area.reset_index().corr()['total_area'][0]
# Out:
# -0.8446643846451344

# %%
# Изменение медианной цены за квадратный метр по годам
year_exposition_price_area = total.groupby('year_exposition')['price_area'].median()
year_exposition_price_area.reset_index().plot.scatter(x = 'year_exposition', y='price_area', title='Изменение цены за квадратный метр по годам');
plt.ylabel('Цена за кваратный метр')
plt.xlabel('Год')
year_exposition_price_area.reset_index().corr()['price_area'][0]
# Out:
# 0.33404426221209615

# %%
# Изменение медианной цены за квадратный метр по годам
year_exposition_count = total.groupby('year_exposition')['price_area'].count()
year_exposition_count.reset_index().plot.scatter(x = 'year_exposition', y='price_area', title='Изменение количества объявлений по годам');
plt.ylabel('Количество объявлений')
plt.xlabel('Год')
year_exposition_count.reset_index().corr()['price_area'][0]
# Out:
# 0.6179215244997581

# %%
# Коэффициенты корреляции
import seaborn as sns
import numpy as np
fig, ax = plt.subplots(figsize=(15, 15))
corr_data = total.drop(['floor_category', 'total_images', 'is_apartment', 'studio', 'open_plan', 'month_exposition', 'weekday_exposition'], axis=1).corr()
corr_data[np.abs(corr_data) < 0.3] = 0
sns.heatmap(corr_data.round(2), annot=True, cmap='RdYlGn');

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Коэффициент корреляции рассчитывается для всех зависимостей из задания, исключая параметры - день недели и месяц — это не эффективно, т.к. это нелинейные параметры
#
# чтобы они стали линейными, январь месяц 2015 года должен стать третьим и т.д., т.е. мы должны сделать перекодировку ...

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить расчет коэффициента корреляции для поиска линейных зависимостей для пар жилая площадь - цена и площадь кухни - цена
#
# Представленные коэф. рассчитаны для других пар параметров
#
#         жилая площадь    0.924085
#         площадь кухни    0.522547

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Количество комнат и общая площадь больше всего влияют на общую (полную) стоимость объекта. С годами площадь продаваемых квартир уменьшалась, а цена уменьшалась до середины 2016 года, а после - росла. Следовательно, квадратный метр жилья до 2016 года уменьшался, а после - резко рос. Количество объявлений со временем также росло. Резкий спад кол-ва объявлений в 2019 году связан с тем, что статистика по этому году собрана в диапазоне январь-май.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Если смотреть только на изменение цены по годам мы можем сделать некорректный вывод, что цены падали, а на самом деле цена это параметр на который влияет несколько других факторов, по этой причине можно посмотреть на основные из них:
#
# + изменение кол-ва записей — принять решение о достаточности данных для анализа и сравнения (сравнивать 100 объявлений и 8000, а возможно, что они еще и из разных локаций, не совсем корректно)
# + изменение площади, как основного параметра от которого зависит стоимость квартиры, в 2017-2018 гг. на сервис или рынок ИТ-торговли недвижимостью пришел массовый продавец, и средние значения упали ..., а за ней и цена
# + изменение кол-ва поданных объявлений из разных локаций, т.к. есть питерские квартиры, а есть выборгские квартиры и стоят они по разному, и в разные годы могло быть больше квартир из определенной локации
# + полнота периода для анализа, 2014 и 2019 гг. неполные, а у нас есть сезонные колебания цен, например летнее снижение цен
# + изменение доли дорогих категорий в общей выборке (средние этажи)
#
# и т.д.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />На твое усмотрение
#
# Если мы перешли на исследование стоимости кв. метра, стоит исследовать изменение доли квартир: доля дорогих локаций против дешевых, например 1 кв. м. в Питере стоит почти в 2 раза дороже чем в г.Выборге

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __На твое усмотрение__
#
#
#         Доля 10 городов с самыми дорогими квартирами (количество объявлений): 0.7136859398530553
#         Доля 10 городов с самыми дешевыми квартирами (количество объявлений): 0.0007757951900698216
#
# Не абсолютную долю, а изменение этой доли по годам. Плюс стоит поменять алгоритм, например в категории дорогих локаций оставить все города, где стоимость кв. метра превышает 100 тыс.руб., в дешевую категорию поместить все остальные
#
#
#         На твое усмотрение
#
#         Если мы перешли на исследование стоимости кв. метра, стоит исследовать изменение доли квартир: доля дорогих локаций против дешевых, например 1 кв. м. в Питере стоит почти в 2 раза дороже чем в г.Выборге

# %%
# Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений
local_price_area = total.groupby('locality_name').agg({'locality_name': 'count', 'price_area': 'mean'})
local_price_area.columns = ['count', 'price_area']
local_price_area = local_price_area.sort_values(by='count', ascending=False).round(1)
display(local_price_area[:10])
(local_price_area[:10].reset_index()
 .plot(x='locality_name', y='price_area', kind='bar', legend=False, title='ТОП 10 населенных пунктов', figsize=(10, 6)));
plt.ylabel('Цена квадратного метра')
plt.xlabel('Населенный пункт')
# Out:
#                    count  price_area
# locality_name
# Санкт-Петербург    14334    110298.1
# поселок Мурино       549     85650.9
# посёлок Шушары       429     78244.6
# Всеволожск           373     68501.1
# Пушкин               340    101630.9
# Колпино              331     75416.8
# посёлок Парголово    321     90290.4
# Гатчина              299     68489.0
# деревня Кудрово      279     92912.6
# Выборг               220     57900.5
# Text(0.5, 0, 'Населенный пункт')

# %%
print('Доля 10 городов с самыми дорогими квартирами (количество объявлений):', 
      (local_price_area.
       sort_values(by='price_area', ascending=False)['count']
       .head(10).sum()) / (local_price_area
                          .sort_values(by='price_area', ascending=False)['count'].sum()))
print('Доля 10 городов с самыми дешевыми квартирами (количество объявлений):', 
      (local_price_area.
       sort_values(by='price_area', ascending=False)['count']
       .tail(10).sum()) / (local_price_area
                          .sort_values(by='price_area', ascending=False)['count'].sum()))
# Out:
# Доля 10 городов с самыми дорогими квартирами (количество объявлений): 0.7136859398530553
# Доля 10 городов с самыми дешевыми квартирами (количество объявлений): 0.0007757951900698216

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />      Можно развернуть график
#
#      kind='barh'

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#             Гатчина	301	68550.772693
#             деревня Кудрово	284	93003.249508
#             Выборг	225	57994.757376

# %%
# Выделим населённые пункты с самой высокой и низкой стоимостью квадратного метра
local_price_area.sort_values(by='price_area', ascending=False)
local_price_area.sort_values(by='price_area', ascending=False).head(10)
# Out:
#                    count  price_area
# locality_name
# поселок Лисий Нос      2    113728.3
# Санкт-Петербург    14334    110298.1
# Пушкин               340    101630.9
# Сестрорецк           170    101622.3
# Зеленогорск           22    100636.5
# Кудрово              160     99984.7
# посёлок Левашово       1     96997.7
# деревня Мистолово     10     95630.3
# деревня Кудрово      279     92912.6
# посёлок Парголово    321     90290.4

# %% [markdown]
# Самая высокая стоимость квадратного метра в поселок Лисий Нос. Это, я так понимаю, питерская Рублевка. Далее - в Санкт-Петербурге. Самая низкая - в деревне Старополье.

# %%
# Найдем среднюю стоимость каждого килоометра в Санкт-Петербурге
#iterFM = total.query('locality_name == "Санкт-Петербург"')[['last_price', 'cityCenters_nearest_km']].dropna().reset_index(drop=True)

#PiterFM['price_nearest_km'] = PiterFM['last_price'] / PiterFM['cityCenters_nearest_km']
#PiterFM_price_nearest_km = PiterFM.pivot_table(index='cityCenters_nearest_km', values='price_nearest_km')
#PiterFM_price_nearest_km.reset_index().plot.scatter(x = 'cityCenters_nearest_km', y='price_nearest_km', title='Средняя цена за км')

# %% [markdown]
# Чем дальше от центра, тем средняя цена каждого километра уменьшается, что закономерно.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Можешь объяснить физический смысл показателя
#
#         PiterFM['price_nearest_km'] = PiterFM['last_price'] / PiterFM['cityCenters_nearest_km']
#
# что это такое и что он отражает

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Отношение цены к расстоянию от центра - стоимость 1 километра для конкретной квартиры

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Это ошибочный показатель
#
#         PiterFM['price_nearest_km'] = PiterFM['last_price'] / PiterFM['cityCenters_nearest_km']
#
# Возьмем 10 условных квартир равной стоимостью 10 млн. руб., но расположенных на первом, втором, третьем и т.д. километрах от центра.
#
# При твоем способе подсчета если 10 млн. руб. разделить на само значение километра мы получим 10, 5, 3.33 ... млн. руб. на км., но квартиры по стоимости равны ...., а в выводе мы можем предположить, что цена падает, что будет ошибкой

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Для выполнения 5-го пункта стоит сгруппировать и найти среднюю стоимость только питерских квартир на каждом километре, на этих данных построить линейный график, где по оси х будут округленные км., а по оси у - средняя стоимость всех квартир на этом км.
#
# Шаг 4.
#
# 5.	Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %%
# Найдем среднюю стоимость каждого килоометра в Санкт-Петербурге
PiterFM = data.query('locality_name == "Санкт-Петербург"')
PiterFM['cityCenters_nearest_km'] = PiterFM['cityCenters_nearest'] / 1000
PiterFM = PiterFM.dropna(subset=['cityCenters_nearest_km'])
PiterFM['cityCenters_nearest_km'] = PiterFM['cityCenters_nearest_km'].astype('int')
PiterFM['price_area'] = PiterFM['last_price'] / PiterFM['total_area']
PiterFM_km = PiterFM.groupby('cityCenters_nearest_km').mean().reset_index()
PiterFM_km.plot(x = 'cityCenters_nearest_km', y='price_area', title='Средняя цена за км', figsize=(10, 6), grid=True)
plt.ylabel('Цена квадратного метра')
plt.xlabel('Расстояние от центра, км')
# Out:
# Text(0.5, 0, 'Расстояние от центра, км')

# %%
# Стоимость квартир на 27 км
(
data_upd1.query('27000 <= cityCenters_nearest <= 27500')
    .groupby('locality_name')['last_price']
    .mean()
    .sort_values(ascending=False)
)
# Out:
# locality_name
# Санкт-Петербург            8.300000e+06
# Пушкин                     7.315792e+06
# посёлок Металлострой       3.840950e+06
# посёлок Александровская    3.750000e+06
# Красное Село               3.000000e+06
# посёлок Петро-Славянка     1.980000e+06
# Name: last_price, dtype: float64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# Отдаляясь от цетнра, стоимость квадратного метра уменьшается. Однако, на 6-7 км цена возрастает до уровня цены на 3 км, так как там возрастает концентрация квартит "в центре". Резкий рост цены на 27 км объясняется тем, что там располагается всего 2 квартиры, и у одной из них цена за квадрат почти втрое выше. Это завышает среднюю и медианные цены.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Для решения задачи
#
#         Стоит изучить записи, которые привели к выбросу на 27-м км., у нас аномалии на питерских квартирах ..
#
# стоит выполнить фильтрацию данных: оставить только питерские квартиры и только с 27-го километра

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента №2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> На 27м километре всего 2 квартиры, и у одной из них цена за квадрат почти втрое выше. Это завышает среднюю и медианные цены

# %%
PiterFM.query('26 <= cityCenters_nearest_km <= 27').sort_values(by='price_area', ascending=False)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 748              13  14350000.0        74.0           2017-11-28      2
# 14146            18   4150000.0        36.0           2018-09-05      1
# 5961              6   2250000.0        32.0           2018-02-27      1
# 18378             9   2600000.0        46.0           2017-11-10      1
# 7732             20   3975000.0        74.0           2018-08-20      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 748              3.13           5.0         30.0      3          NaN   False
# 14146            2.50          10.0         20.0      7          NaN   False
# 5961              NaN           2.0         16.5      2          NaN   False
# 18378             NaN           2.0         20.0      1          NaN   False
# 7732             3.20           3.0         43.8      2          NaN   False
#
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается, кол-во наблюдений важный параметр для оценки качества данных
#
# у нас всего 2 записи на 27-м км., одна из которых с аномальной ценой, по этой причине мы отвергаем данное наблюдение

# %%
PiterFM.groupby('cityCenters_nearest_km')['price_area'].quantile([0, .25, .5, .75, 1]).loc[3:5]
# Out:
# cityCenters_nearest_km
# 3                       0.00    6.217949e+04
#                         0.25    9.256965e+04
#                         0.50    1.100800e+05
#                         0.75    1.381453e+05
#                         1.00    1.907500e+06
# 4                       0.00    1.586157e+04
#                         0.25    1.005850e+05
#                         0.50    1.260870e+05
#                         0.75    1.558099e+05
#                         1.00    5.520000e+05
# 5                       0.00    1.534527e+04
#                         0.25    1.026490e+05
#                         0.50    1.260417e+05
#                         0.75    1.617194e+05
#                         1.00    8.132530e+05
# Name: price_area, dtype: float64

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре

# %%
# Доля объявлений на удалении от центра в пределах Санкт 
rrr = data.pivot_table(index='cityCenters_nearest', values='last_price', aggfunc=('count')).reset_index()
rrr['cityCenters_nearest_km'] = rrr['cityCenters_nearest'] / 1000
rrr = rrr.dropna(subset=['cityCenters_nearest_km'])
rrr['cityCenters_nearest_km'] = rrr['cityCenters_nearest_km'].astype('int')
rrr = rrr.groupby('cityCenters_nearest_km').sum().reset_index()
rrr = rrr[['cityCenters_nearest_km', 'last_price']].rename(columns={'last_price': 'count'})
rrr['доля'] = rrr['count'] / rrr['count'].sum()
rrr.plot(x = 'cityCenters_nearest_km', y='доля', title='Доля объявлений по км', figsize=(10, 6), grid=True)
plt.ylabel('Доля объявлений')
plt.xlabel('Расстояние от центра, км')
# Out:
# Text(0.5, 0, 'Расстояние от центра, км')

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    Для решения задачи
#
#     Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре
#
# стоит выполнить группировку данных на базе питерских квартир

# %%
cityCenters_floor_category = (total.groupby(['cityCenters_nearest_km', 'floor_category'])['price_area']
                              .agg(['count', 'median']))
cityCenters_floor_category['доля_квартир'] = cityCenters_floor_category['count'] / (cityCenters_floor_category
                                                                            .groupby('cityCenters_nearest_km')['count']
                                                                            .transform('sum'))
first = cityCenters_floor_category.query('floor_category == "первый"').reset_index()
other = cityCenters_floor_category.query('floor_category == "другой"').reset_index()
last = cityCenters_floor_category.query('floor_category == "последний"').reset_index()

display(cityCenters_floor_category.query('3 <= cityCenters_nearest_km <= 6'))

plt.figure(figsize=(15,8))
plt.plot(first['cityCenters_nearest_km'], first['median'], label='первый');
plt.plot(other['cityCenters_nearest_km'], other['median'], label='другой');
plt.plot(last['cityCenters_nearest_km'], last['median'], label='последний');
plt.legend(loc='upper right')
plt.xlim (0, 30)
plt.title('Медианная цена за квадратный метр различных категорий этажей в зависимости от расстояния от центра')
plt.ylabel('Цена за квардратный метр')
plt.xlabel('Расстояние от центра, км')
plt.grid()
# Out:
#                                        count         median  доля_квартир
# cityCenters_nearest_km floor_category
# 3.0                    другой            165  106911.447084      0.604396
#                        первый             46  102062.074830      0.168498
#                        последний          62  104862.958840      0.227106
# 4.0                    другой            409  116842.105263      0.725177
#                        первый             65  107017.543860      0.115248
#                        последний          90  105726.662500      0.159574
# 5.0                    другой            564  127019.057670      0.762162
#                        первый             68   99744.897959      0.091892
#                        последний         108  125520.833333      0.145946
# 6.0                    другой            362  131612.012987      0.741803
#                        первый             57  113188.679245      0.116803
# ...

# %%
plt.figure(figsize=(15,8))
plt.plot(first['cityCenters_nearest_km'], first['доля_квартир'], label='первый');
plt.plot(other['cityCenters_nearest_km'], other['доля_квартир'], label='другой');
plt.plot(last['cityCenters_nearest_km'], last['доля_квартир'], label='последний');
plt.legend(loc='upper right')
plt.xlim (0, 30)
plt.title('Доля объявлений различных категорий этажей на каждом расстояния от центра')
plt.ylabel('Доля объявлений')
plt.xlabel('Расстояние от центра, км')
plt.grid()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Принимается, подправим акценты вывода
#
# ![image.png](attachment:image.png)
#
# слева график для 3-го км., справа для 5-го км. (цифры для графиков не твои, но это не принципиально)
#
# Две стопки монет: в одной 8 золотых и 2 серебряные, во второй 6 золотых и 4 серебряные. В какой стопке средняя цена одной монеты будет дороже?
#
# Размер доли категорий квартир с более дешевой стоимостью намного больше на 3-м километре, чем на пятом, что является одной из причин падения и пика...
#
# возможно к этому фактору добавляются и другие
#
#
# __Для квартир, находящихся после 5-7-го километров, данный фактор уже не играет существенной роли, кроме 20-го км.__

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В данном проекте необходимо было выполнить предобработку данных и изучить их, чтобы найти интересные особенности и зависимости, которые существуют на рынке недвижимости Ленинградской области в период 2014-2019 года.
# На первом этапе были удалены явные дубликаты, неявные дубликаты в названиях населённых пунктов, именен тип данных, заполнены по возможности пропущенные значения, удалены редкие и выбивающиеся значения (аномалии) во всех столбцах.
# После была проведена категоризация данных.
# Третьим этапом проекта был исследовательский анализ данных, в котором были проаналицированы основные тенденции и особенности. Выяснили, что обычная продажа квартиры осуществляется за 45 дня (первый процентиль). Дольгой можно назвать продажу более 231 день (третий процентиль), а необычно долгой - 510 дней. На цену жилья больше всего влияют количество комнат и общая площадь. Самая высокая стоимость квадратного метра оказалась в поселок Лисий Нос. Самая низкая - в деревне Старополье. Также была потроена тенденция изменения средней цены кажого километра в завсисимости от уаления от центра Санкт-Петербурга. Отдаляясь от цетнра, стоимость квадратного метра уменьшается. Однако, на 6-7 км цена возрастает до уровня цены на 3 км, так как там возрастает концентрация квартит "в центре". Резкий рост цены на 27 км объясняется тем, что на данной отметки всего два объявления и цена квадратного метра одного из них почти втрое выше другого, что завысило средние показатели. Было обнаружено, что количество комнат и общая площадь больше всего влияют на общую (полную) стоимость объекта. С годами площадь продаваемых квартир уменьшалась, а цена уменьшалась до середины 2016 года, а после - росла. Следовательно, квадратный метр жилья до 2016 года уменьшался, а после - резко рос. Количество объявлений со временем также росло. Резкий спад кол-ва объявлений в 2019 году связан с тем, что статистика по этому году собрана в диапазоне январь-май. Цена квадратного метра на первом этаже ниже, чем на последнем и других этажах на всем удалении от центра. Доля объявлений в категории этажа "другой" в несколько раз больше, чем дугих категорий, на всем удалении от центра.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев
#
#         м.б. появятся новые инсайты

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец
#
# Критические ❌ комментарии
#
#
# + проверить корректность заполнения пропусков синтетическими данными
# + настроить фильтрацию редких значений в п. 2.4
# + подправить функцию категоризации этажности
# + подправить гистограммы в п.4.1
# + пересчитать скорость продаж
# + подправить расчет коэф. корреляции
# + добавить вывод в п. 4.3
# + добавить график в ТОП-10
# + поправить выполнение и исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)

# %% [markdown]
# ### Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %%
# check
price_pivot_area = data.pivot_table(index='last_price', values=([
    'total_area', 'living_area', 'kitchen_area']), aggfunc='median')
price_pivot_area = price_pivot_area.reset_index()
# Посмотрим на диаграммы рассеяния для столбцов 'total_area', 'living_area', 'kitchen_area'.
for row in ['total_area', 'living_area', 'kitchen_area']:
    sns.relplot(data=price_pivot_area, x='last_price', y=row, kind='scatter')

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
